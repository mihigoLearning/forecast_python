# %%
import pandas as pd
import numpy as np
import warnings
import itertools
import matplotlib
import matplotlib.pyplot as plt
from pylab import rcParams
import statsmodels.api as sm
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
from statsmodels.tsa.stattools import adfuller

# Ignore the warning, can comment this 
warnings.filterwarnings("ignore")

# For graphing purpose, can change 
plt.style.use('seaborn-bright')
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %%
df = pd.read_csv('../data/daily-total-female-births.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Set the date as index 
df = df.set_index('Date')
# Select the proper time period for weekly aggreagation -- changed to M monthly , W to weekly
df = df['1959-01-04':'1959-11-30'].resample('M').sum()

# %%
y = df['Births']
fig, ax = plt.subplots(figsize=(20, 6))
#ax.plot(y,marker='.', linestyle='-', linewidth=0.5, label='Weekly')
ax.plot(y.resample('M').mean(),marker='o', markersize=8, linestyle='-', label='Monthly Mean Resample')
ax.set_ylabel('Births')
ax.legend();

# %%
y_to_train = y[:'1959-01-31'] # dataset to train
y_to_val = y['1959-12-30':] # last X months for test  
predict_date = len(y) - len(y[:'1959-12-30']) # the number of data points for the test set

# %%
import itertools

def sarima_grid_search(y,seasonal_period):
    p = d = q = range(0, 2)
    pdq = list(itertools.product(p, d, q))
    seasonal_pdq = [(x[0], x[1], x[2],seasonal_period) for x in list(itertools.product(p, d, q))]
    
    mini = float('+inf')
    
    
    for param in pdq:
        for param_seasonal in seasonal_pdq:
            try:
                mod = sm.tsa.statespace.SARIMAX(y,
                                                order=param,
                                                seasonal_order=param_seasonal,
                                                enforce_stationarity=False,
                                                enforce_invertibility=False)

                results = mod.fit()
                
                if results.aic < mini:
                    mini = results.aic
                    param_mini = param
                    param_seasonal_mini = param_seasonal

#                 print('SARIMA{}x{} - AIC:{}'.format(param, param_seasonal, results.aic))
            except:
                continue
    print('The set of parameters with the minimum AIC is: SARIMA{}x{} - AIC:{}'.format(param_mini, param_seasonal_mini, mini))

# %%
sarima_grid_search(y,6)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.79629D+00    |proj g|=  1.62041D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      2      4      1     0     0   2.805D-07   7.796D+00
#   F =   7.7961800836108770
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.03280D+01    |proj g|=  8.03390D-01
#
# At iterate    5    f=  3.09827D+00    |proj g|=  4.24087D-04
#
# At iterate   10    f=  3.06565D+00    |proj g|=  1.76509D-03
#
# At iterate   15    f=  2.98993D+00    |proj g|=  1.59118D-03
#
# At iterate   20    f=  2.97519D+00    |proj g|=  8.18688D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     22     36      1     0     0   9.293D-07   2.975D+00
#   F =   2.9751887602312723
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.49984D+00    |proj g|=  3.50857D-03
#
# At iterate    5    f=  2.42260D+00    |proj g|=  3.03387D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      6      8      1     0     0   2.530D-06   2.423D+00
#   F =   2.4225784513086310
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.18729D+00    |proj g|=  3.55924D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     15      1     0     0   3.559D-03   2.187D+00
#   F =   2.1872931085004730
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.03280D+01    |proj g|=  6.62745D+01
#
# At iterate    5    f=  2.01205D+00    |proj g|=  1.64746D-02
#
# At iterate   10    f=  2.01180D+00    |proj g|=  2.91312D-02
#
# At iterate   15    f=  2.00151D+00    |proj g|=  1.10272D+00
#
# At iterate   20    f=  1.84240D+00    |proj g|=  5.27834D+00
#
# At iterate   25    f=  1.78728D+00    |proj g|=  2.24369D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     28     60      1     0     0   6.089D-05   1.787D+00
#   F =   1.7872783808803470
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.64675D+00    |proj g|=  2.28232D-01
#
# At iterate    5    f=  6.77848D+00    |proj g|=  4.15830D-04
#
# At iterate   10    f=  6.77841D+00    |proj g|=  1.13376D-02
#
# At iterate   15    f=  6.76847D+00    |proj g|=  1.61625D-01
#
# At iterate   20    f=  6.60472D+00    |proj g|=  2.40277D-01
#
# At iterate   25    f=  6.56823D+00    |proj g|=  2.96147D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     27     39      1     0     0   7.761D-07   6.568D+00
#   F =   6.5682239631836188
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.55950D+00    |proj g|=  7.47388D-02
#
# At iterate    5    f=  2.25477D+00    |proj g|=  1.52639D-04
#
# At iterate   10    f=  2.25469D+00    |proj g|=  4.30638D-03
#
# At iterate   15    f=  2.24570D+00    |proj g|=  5.26663D-02
#
# At iterate   20    f=  2.11087D+00    |proj g|=  7.69776D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     24     38      1     0     0   9.124D-06   2.110D+00
#   F =   2.1095639278614007
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.70905D+00    |proj g|=  1.94410D-02
#
# At iterate    5    f=  1.70817D+00    |proj g|=  1.16594D-02
#
# At iterate   10    f=  1.67364D+00    |proj g|=  7.50954D-02
#
# At iterate   15    f=  1.66125D+00    |proj g|=  2.89602D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     15     22      1     0     0   2.896D-06   1.661D+00
#   F =   1.6612540059500638
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.25344D+00    |proj g|=  1.30125D-01
#
# At iterate    5    f=  3.68620D+00    |proj g|=  6.12689D-03
#
# At iterate   10    f=  3.68611D+00    |proj g|=  2.38307D-03
#
# At iterate   15    f=  3.68136D+00    |proj g|=  5.13176D-02
#
# At iterate   20    f=  3.25021D+00    |proj g|=  1.24876D+00
#
# At iterate   25    f=  2.40862D+00    |proj g|=  8.23264D+00
#
# At iterate   30    f=  2.11093D+00    |proj g|=  4.83668D+00
#
# At iterate   35    f=  2.08292D+00    |proj g|=  7.51943D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     37     74      1     0     0   2.565D-06   2.083D+00
#   F =   2.0829156052989295
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.55950D+00    |proj g|=  7.47388D-02
#
# At iterate    5    f=  2.22249D+00    |proj g|=  7.34604D-02
#
# At iterate   10    f=  2.21172D+00    |proj g|=  1.51674D-03
#
# At iterate   15    f=  2.21171D+00    |proj g|=  2.05454D-04
#
# At iterate   20    f=  2.21155D+00    |proj g|=  5.41419D-03
#
# At iterate   25    f=  2.19414D+00    |proj g|=  9.97531D-02
#
# At iterate   30    f=  1.49322D+00    |proj g|=  2.14792D+00
#
# At iterate   35    f=  1.32336D+00    |proj g|=  8.54361D-01
#
# At iterate   40    f=  1.32250D+00    |proj g|=  6.13957D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     42     82      1     0     0   1.376D-04   1.322D+00
#   F =   1.3224995198590872
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.50409D+00    |proj g|=  2.76738D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      4      5      1     0     0   1.428D-06   4.498D+00
#   F =   4.4979385323150032
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.60116D+00    |proj g|=  6.06462D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      8      1     0     0   1.989D-05   1.552D+00
#   F =   1.5519355845024032
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.54800D+00    |proj g|=  3.07929D-02
#
# At iterate    5    f=  1.38831D+00    |proj g|=  7.96190D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      8      9      1     0     0   7.152D-07   1.388D+00
#   F =   1.3875633838998349
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.74272D+00    |proj g|=  3.53459D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   3.535D-06   1.743D+00
#   F =   1.7427181470059878
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.60116D+00    |proj g|=  3.04746D-01
#
# At iterate    5    f=  1.35782D+00    |proj g|=  4.02707D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      9     15      1     0     0   5.572D-06   1.346D+00
#   F =   1.3457065158953685
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.99600D+00    |proj g|=  1.43078D-01
#
# At iterate    5    f=  3.98662D+00    |proj g|=  1.34994D-02
#
# At iterate   10    f=  3.97938D+00    |proj g|=  5.18987D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     14     16      1     0     0   8.761D-07   3.978D+00
#   F =   3.9781820316819547
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.02204D+00    |proj g|=  1.75042D-01
#
# At iterate    5    f=  9.34582D-01    |proj g|=  9.92465D-02
#
# At iterate   10    f=  9.03731D-01    |proj g|=  1.41442D-03
#
# At iterate   15    f=  9.03721D-01    |proj g|=  1.67765D-04
#
# At iterate   20    f=  9.03697D-01    |proj g|=  8.60902D-04
#
# At iterate   25    f=  9.03676D-01    |proj g|=  8.29564D-04
#
# At iterate   30    f=  9.03657D-01    |proj g|=  1.60496D-04
#
# At iterate   35    f=  9.03653D-01    |proj g|=  2.94777D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     36     47      1     0     0   6.760D-06   9.037D-01
#   F =  0.90365266562425650
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.35401D+00    |proj g|=  5.40219D-03
#   ys=-1.070E+01  -gs= 1.788E-01 BFGS update SKIPPED
#   ys=-5.911E+00  -gs= 1.765E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5     79      3     2     0   7.940D+03   4.451D+00
#   F =   4.4514138903210991
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.88021D+00    |proj g|=  1.82850D-02
#
# At iterate    5    f=  1.85430D+00    |proj g|=  8.42147D-02
#
# At iterate   10    f=  1.61409D+00    |proj g|=  5.57546D-02
#
# At iterate   15    f=  1.60644D+00    |proj g|=  2.34108D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     17     31      1     0     0   7.199D-07   1.606D+00
#   F =   1.6064383936400404
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.02204D+00    |proj g|=  1.75042D-01
#
# At iterate    5    f=  9.32410D-01    |proj g|=  3.84303D-03
#
# At iterate   10    f=  9.28711D-01    |proj g|=  4.02335D-02
#
# At iterate   15    f=  8.03012D-01    |proj g|=  5.60593D-02
#
# At iterate   20    f=  5.89858D-01    |proj g|=  4.49365D-01
#
# At iterate   25    f=  5.57559D-01    |proj g|=  2.91149D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     29     49      1     0     0   5.057D-05   5.576D-01
#   F =  0.55755509906146805
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.89371D+00    |proj g|=  2.60158D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     14      1     0     0   2.602D-03   4.894D+00
#   F =   4.8937075205996061
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.07496D+00    |proj g|=  2.32710D+00
#
# At iterate    5    f=  2.05837D+00    |proj g|=  2.20529D+00
#
# At iterate   10    f=  2.04091D+00    |proj g|=  5.43066D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     11     19      1     0     0   3.937D-05   2.041D+00
#   F =   2.0409066346334312
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.78997D+00    |proj g|=  6.46152D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     12      1     0     0   6.460D-05   1.790D+00
#   F =   1.7899729912710214
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.84369D+00    |proj g|=  1.10998D-01
#
# At iterate    5    f=  1.78843D+00    |proj g|=  5.54453D-01
#
# At iterate   10    f=  1.77850D+00    |proj g|=  3.55772D-01
#
# At iterate   15    f=  1.54854D+00    |proj g|=  2.73532D+00
#
# At iterate   20    f=  1.41647D+00    |proj g|=  1.28809D-01
#
# At iterate   25    f=  1.41641D+00    |proj g|=  1.47851D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     25     46      1     0     0   1.479D-06   1.416D+00
#   F =   1.4164062859552133
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.07496D+00    |proj g|=  2.32710D+00
#
# At iterate    5    f=  1.79449D+00    |proj g|=  2.81832D-01
#
# At iterate   10    f=  1.78518D+00    |proj g|=  7.86360D-02
#
# At iterate   15    f=  1.78487D+00    |proj g|=  1.27028D-01
#
# At iterate   20    f=  1.78111D+00    |proj g|=  1.46906D-01
#
# At iterate   25    f=  1.69010D+00    |proj g|=  1.41993D+01
#
# At iterate   30    f=  1.41659D+00    |proj g|=  3.56201D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     34     50      1     0     0   2.630D-05   1.416D+00
#   F =   1.4164062854792645
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.44779D+00    |proj g|=  1.87151D+00
#
# At iterate    5    f=  4.44374D+00    |proj g|=  2.41309D-01
#
# At iterate   10    f=  4.44355D+00    |proj g|=  1.59577D-03
#
# At iterate   15    f=  4.44351D+00    |proj g|=  3.74468D-02
#
# At iterate   20    f=  4.44209D+00    |proj g|=  2.53305D-01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     24     29      1     0     0   6.468D-05   4.442D+00
#   F =   4.4417756874018863
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.57452D+00    |proj g|=  2.54170D+00
#
# At iterate    5    f=  1.54538D+00    |proj g|=  1.60084D+00
#
# At iterate   10    f=  1.49312D+00    |proj g|=  1.19752D-03
#
# At iterate   15    f=  1.49296D+00    |proj g|=  1.05539D-02
#
# At iterate   20    f=  1.48428D+00    |proj g|=  3.05378D-02
#
# At iterate   25    f=  1.48359D+00    |proj g|=  1.39885D-03
#
# At iterate   30    f=  1.48358D+00    |proj g|=  6.91150D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     33     39      1     0     0   6.782D-04   1.484D+00
#   F =   1.4835773514207515
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.66526D+12    |proj g|=  1.70309D+17
#
# At iterate    5    f=  7.27648D+05    |proj g|=  7.40522D+07
#
# At iterate   10    f=  9.86650D+04    |proj g|=  3.68079D+06
#
# At iterate   15    f=  1.19653D+04    |proj g|=  1.70136D+05
#
# At iterate   20    f=  1.38363D+03    |proj g|=  8.36281D+03
#
# At iterate   25    f=  1.74821D+02    |proj g|=  3.96575D+02
#
# At iterate   30    f=  2.03271D+01    |proj g|=  1.94982D+01
#
# At iterate   35    f=  1.80560D+00    |proj g|=  1.24682D+00
#
# At iterate   40    f=  1.33000D+00    |proj g|=  7.34817D-02
#
# At iterate   45    f=  1.32688D+00    |proj g|=  4.03828D-02
#
# At iterate   50    f=  1.32220D+00    |proj g|=  4.84555D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     50     67      1     0     0   4.846D-02   1.322D+00
#   F =   1.3221969583392801
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.86801D+00    |proj g|=  8.04580D-02
#
# At iterate    5    f=  1.83019D+00    |proj g|=  1.91511D-01
#
# At iterate   10    f=  1.81937D+00    |proj g|=  1.38417D-01
#
# At iterate   15    f=  1.81569D+00    |proj g|=  1.36886D-02
#
# At iterate   20    f=  1.81506D+00    |proj g|=  1.57153D-01
#
# At iterate   25    f=  1.78008D+00    |proj g|=  1.22302D-01
#
# At iterate   30    f=  1.69704D+00    |proj g|=  6.45309D-01
#
# At iterate   35    f=  1.66970D+00    |proj g|=  8.22261D-01
#
# At iterate   40    f=  1.58818D+00    |proj g|=  2.89642D+00
#
# At iterate   45    f=  1.38961D+00    |proj g|=  7.54084D+00
#
# At iterate   50    f=  1.33911D+00    |proj g|=  4.80539D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     50     81      1     0     0   4.805D-02   1.339D+00
#   F =   1.3391122476336266
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.57452D+00    |proj g|=  2.54170D+00
#
# At iterate    5    f=  1.41402D+00    |proj g|=  1.64004D-01
#
# At iterate   10    f=  1.39308D+00    |proj g|=  5.07183D-02
#
# At iterate   15    f=  1.38997D+00    |proj g|=  4.47894D-02
#
# At iterate   20    f=  1.38960D+00    |proj g|=  2.22397D-02
#
# At iterate   25    f=  1.37723D+00    |proj g|=  1.31499D-01
#
# At iterate   30    f=  1.32509D+00    |proj g|=  1.09197D+00
#
# At iterate   35    f=  1.31561D+00    |proj g|=  6.64387D-03
#
# At iterate   40    f=  1.31561D+00    |proj g|=  3.52129D-04
#
# At iterate   45    f=  1.31559D+00    |proj g|=  8.90604D-03
#
# At iterate   50    f=  1.31552D+00    |proj g|=  1.36016D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     50     69      1     0     0   1.360D-02   1.316D+00
#   F =   1.3155175675541075
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.49118D+00    |proj g|=  4.25171D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   4.252D-06   4.491D+00
#   F =   4.4911829154251128
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.57282D+00    |proj g|=  9.01628D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      3     12      1     0     0   3.156D-05   1.551D+00
#   F =   1.5512884445945843
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.38270D+00    |proj g|=  1.22800D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   1.228D-06   1.383D+00
#   F =   1.3826997085894257
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.39939D+00    |proj g|=  4.62472D-02
#
# At iterate    5    f=  1.36637D+00    |proj g|=  5.15266D-03
#
# At iterate   10    f=  1.27679D+00    |proj g|=  3.42008D-01
#
# At iterate   15    f=  1.08591D+00    |proj g|=  2.70114D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     19     28      1     0     0   2.592D-05   1.086D+00
#   F =   1.0855739714412893
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.57282D+00    |proj g|=  2.27304D-01
#
# At iterate    5    f=  1.36892D+00    |proj g|=  3.06245D-02
#
# At iterate   10    f=  1.36472D+00    |proj g|=  8.53199D-03
#
# At iterate   15    f=  1.26812D+00    |proj g|=  2.10470D-01
#
# At iterate   20    f=  1.09617D+00    |proj g|=  2.45616D-01
#
# At iterate   25    f=  1.08557D+00    |proj g|=  1.87925D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     27     42      1     0     0   7.374D-06   1.086D+00
#   F =   1.0855739714766701
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.44456D+00    |proj g|=  3.06874D-01
#
# At iterate    5    f=  3.97037D+00    |proj g|=  1.19182D-01
#
# At iterate   10    f=  3.96608D+00    |proj g|=  7.37672D-03
#
# At iterate   15    f=  3.95308D+00    |proj g|=  7.29382D-02
#
# At iterate   20    f=  3.94956D+00    |proj g|=  6.33317D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     22     32      1     0     0   2.307D-06   3.950D+00
#   F =   3.9495642008071554
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.13246D+00    |proj g|=  1.24063D-01
#
# At iterate    5    f=  9.64237D-01    |proj g|=  1.09833D-01
#
# At iterate   10    f=  9.39246D-01    |proj g|=  2.27970D-03
#
# At iterate   15    f=  9.20495D-01    |proj g|=  1.03918D-01
#
# At iterate   20    f=  8.60503D-01    |proj g|=  4.29148D-03
#
# At iterate   25    f=  8.60377D-01    |proj g|=  1.69418D-04
#
# At iterate   30    f=  8.60369D-01    |proj g|=  1.19351D-03
#
# At iterate   35    f=  8.60351D-01    |proj g|=  8.85315D-04
#
# At iterate   40    f=  8.60320D-01    |proj g|=  1.39129D-03
#
# At iterate   45    f=  8.60287D-01    |proj g|=  1.05397D-03
#
# At iterate   50    f=  8.60251D-01    |proj g|=  3.81857D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     50     64      1     0     0   3.819D-04   8.603D-01
#   F =  0.86025125161938187
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.97940D-01    |proj g|=  1.38624D-01
#
# At iterate    5    f=  9.41299D-01    |proj g|=  4.78694D-02
#
# At iterate   10    f=  9.39897D-01    |proj g|=  2.19510D-04
#
# At iterate   15    f=  9.39840D-01    |proj g|=  5.54975D-03
#
# At iterate   20    f=  9.39445D-01    |proj g|=  1.92027D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     22     33      1     0     0   4.615D-06   9.394D-01
#   F =  0.93943730459574548
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -0.00000D+00    |proj g|=  0.00000D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      0      1      0     0     0   0.000D+00  -0.000D+00
#   F =  -0.0000000000000000
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.60938D+00    |proj g|=  9.49193D-02
#
# At iterate    5    f=  1.39741D+00    |proj g|=  2.92017D-02
#
# At iterate   10    f=  1.37461D+00    |proj g|=  4.31812D-03
#
# The set of parameters with the minimum AIC is: SARIMA(1, 1, 1)x(1, 0, 1, 6) - AIC:-2.0029130059546425

# %%
# Call this function after pick the right(p,d,q) for SARIMA based on AIC               
def sarima_eva(y,order,seasonal_order,seasonal_period,pred_date,y_to_test):
    
    # fit the model 
    mod = sm.tsa.statespace.SARIMAX(y,
                                order=order,
                                seasonal_order=seasonal_order,
                                enforce_stationarity=False,
                                enforce_invertibility=False)

    results = mod.fit()
    print(results.summary().tables[1])
    

    pred = results.get_prediction(start=pd.to_datetime(pred_date), dynamic=False)
    pred_ci = pred.conf_int()
    y_forecasted = pred.predicted_mean
    mse = ((y_forecasted - y_to_test) ** 2).mean()
    print('The Root Mean Squared Error of SARIMA with season_length={} and dynamic = False {}'.format(seasonal_period,round(np.sqrt(mse), 2)))

    ax = y.plot(label='observed')
    y_forecasted.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))
    ax.fill_between(pred_ci.index,
                    pred_ci.iloc[:, 0],
                    pred_ci.iloc[:, 1], color='k', alpha=.2)

    ax.set_xlabel('Date')
    ax.set_ylabel('Sessions')
    plt.legend()
    plt.show()

    # A better representation of our true predictive power can be obtained using dynamic forecasts. 
    # In this case, we only use information from the time series up to a certain point, 
    # and after that, forecasts are generated using values from previous forecasted time points.
    pred_dynamic = results.get_prediction(start=pd.to_datetime(pred_date), dynamic=True, full_results=True)
    pred_dynamic_ci = pred_dynamic.conf_int()
    y_forecasted_dynamic = pred_dynamic.predicted_mean
    mse_dynamic = ((y_forecasted_dynamic - y_to_test) ** 2).mean()
    print('The Root Mean Squared Error of SARIMA with season_length={} and dynamic = True {}'.format(seasonal_period,round(np.sqrt(mse_dynamic), 2)))

    ax = y.plot(label='observed')
    y_forecasted_dynamic.plot(label='Dynamic Forecast', ax=ax,figsize=(14, 7))
    ax.fill_between(pred_dynamic_ci.index,
                    pred_dynamic_ci.iloc[:, 0],
                    pred_dynamic_ci.iloc[:, 1], color='k', alpha=.2)

    ax.set_xlabel('Date')
    ax.set_ylabel('Sessions')

    plt.legend()
    plt.show()
    
    return (results)

# %%
model = sarima_eva(y,(0, 0, 0),(0, 1, 0, 6),6,'1959-09-30' ,y_to_val)
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      3.577e+04   1.07e+05      0.334      0.739   -1.74e+05    2.46e+05
# ==============================================================================
# The Root Mean Squared Error of SARIMA with season_length=6 and dynamic = False nan
# The Root Mean Squared Error of SARIMA with season_length=6 and dynamic = True nan

# %%
def forecast(model,predict_steps,y):
    
    pred_uc = model.get_forecast(steps=predict_steps)

    #SARIMAXResults.conf_int, can change alpha,the default alpha = .05 returns a 95% confidence interval.
    pred_ci = pred_uc.conf_int()

    ax = y.plot(label='observed', figsize=(14, 7))
#     print(pred_uc.predicted_mean)
    pred_uc.predicted_mean.plot(ax=ax, label='Forecast', color='r')
    ax.fill_between(pred_ci.index,
                    pred_ci.iloc[:, 0],
                    pred_ci.iloc[:, 1], color='k', alpha=.25)
    ax.set_xlabel('Date')
    ax.set_ylabel(y.name)

    plt.legend()
    plt.show()
    
    # Produce the forcasted tables 
    pm = pred_uc.predicted_mean.reset_index()
    pm.columns = ['Date','Predicted_Mean']
    pci = pred_ci.reset_index()
    pci.columns = ['Date','Lower Bound','Upper Bound']
    final_table = pm.join(pci.set_index('Date'), on='Date')
    
    return (final_table)

# %%
final_table = forecast(model,24,y)
#final_table.head()

# %%
### Graphs without the confident interval 
# arma_df = model.predict(start='2020-01-01', end='2023-12-01')
pred_uc = model.get_forecast(steps=51)
ax = y.plot(label='observed', figsize=(14, 7))
#     print(pred_uc.predicted_mean)
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.set_xlabel('Date')
ax.set_ylabel(y.name)

plt.legend()
plt.show()
